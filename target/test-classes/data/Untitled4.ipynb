# %%
import pandas as pd
import numpy as np

# %%
datos=pd.read_csv('players_21.csv')

# %%
df=pd.DataFrame(datos)

# %%
df
# Out:
#        sofifa_id                                         player_url  \
# 0         158023  https://sofifa.com/player/158023/lionel-messi/...
# 1          20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2         200389  https://sofifa.com/player/200389/jan-oblak/210002
# 3         188545  https://sofifa.com/player/188545/robert-lewand...
# 4         190871  https://sofifa.com/player/190871/neymar-da-sil...
# ...          ...                                                ...
# 18939     256679  https://sofifa.com/player/256679/kevin-angulo/...
# 18940     257710  https://sofifa.com/player/257710/mengxuan-zhan...
# 18941     250989  https://sofifa.com/player/250989/zhenghao-wang...
# 18942     257697  https://sofifa.com/player/257697/zitong-chen/2...
# 18943     257936   https://sofifa.com/player/257936/yue-song/210002
#
#               short_name                            long_name  age  \
# 0               L. Messi       Lionel Andrés Messi Cuccittini   33
# ...

# %%
potencial=df['potential']

# %%
df[potencial]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [81], in <cell line: 1>()
# ----> 1 df[potencial]
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:3511, in DataFrame.__getitem__(self, key)
#    3509     if is_iterator(key):
#    3510         key = list(key)
# -> 3511     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3513 # take() does not accept boolean indexers
#    3514 if getattr(indexer, "dtype", None) == bool:
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:5782, in Index._get_indexer_strict(self, key, axis_name)
#    5779 else:
#    5780     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 5782 self._raise_if_missing(keyarr, indexer, axis_name)
#    5784 keyarr = self.take(indexer)
#    5785 if isinstance(key, Index):
#    5786     # GH 42790 - Preserve name from an Index
#
# ...

# %%
 df=pd.read_csv('players_21.csv', sep=',', usecols=("short_name",
                                        "long_name",
                                        "age",
                                        "height_cm",
                                        "weight_kg",
                                        "nationality",
                                        "potential",
                                        "overall",          
                                        "club_name"))

# %%
df
# Out:
#               short_name                            long_name  age  height_cm  \
# 0               L. Messi       Lionel Andrés Messi Cuccittini   33        170
# 1      Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   35        187
# 2               J. Oblak                            Jan Oblak   27        188
# 3         R. Lewandowski                   Robert Lewandowski   31        184
# 4              Neymar Jr        Neymar da Silva Santos Júnior   28        175
# ...                  ...                                  ...  ...        ...
# 18939          K. Angulo                         Kevin Angulo   24        176
# 18940     Zhang Mengxuan                       Mengxuan Zhang   21        177
# 18941      Wang Zhenghao                                  王政豪   20        185
# 18942        Chen Zitong                          Zitong Chen   23        186
# 18943           Song Yue                             Yue Song   28        185
#
# ...

# %%
df['age_range']='A'

# %%
df
# Out:
#               short_name                            long_name  age  height_cm  \
# 0               L. Messi       Lionel Andrés Messi Cuccittini   33        170
# 1      Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   35        187
# 2               J. Oblak                            Jan Oblak   27        188
# 3         R. Lewandowski                   Robert Lewandowski   31        184
# 4              Neymar Jr        Neymar da Silva Santos Júnior   28        175
# ...                  ...                                  ...  ...        ...
# 18939          K. Angulo                         Kevin Angulo   24        176
# 18940     Zhang Mengxuan                       Mengxuan Zhang   21        177
# 18941      Wang Zhenghao                                  王政豪   20        185
# 18942        Chen Zitong                          Zitong Chen   23        186
# 18943           Song Yue                             Yue Song   28        185
#
# ...

# %%
df['potential_vs_overall'][df['potential'].sum()
# Out:
#   Input In [99]
#     df['potential_vs_overall'][df['potential'].sum()
#                                                     ^
# SyntaxError: unexpected EOF while parsing

# %%
df['age_range']=expr("case when age = 27 then 'Male' " +
                       "else 'Unknown' end")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [106], in <cell line: 1>()
# ----> 1 df['age_range']=expr("case when age = 27 then 'Male' " +
#       2                        "else 'Unknown' end")
#
# NameError: name 'expr' is not defined

# %%
df['age_range']= when('age') == 27 , 'A'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [114], in <cell line: 1>()
# ----> 1 df['age_range']= when('age') == 27 , 'A'
#
# TypeError: when() missing 1 required positional argument: 'value'

# %%
df['age_range']= df.select(when(df['age'] == 27, 'A').otherwise('B')
# Out:
#   Input In [118]
#     df['age_range']= df.select(when(df['age'] = '27', 'A').otherwise('B')
#                                     ^
# SyntaxError: expression cannot contain assignment, perhaps you meant "=="?
