# %%
import pandas as pd
datos = pd.read_csv('players_21.csv')
df=pd.DataFrame(datos)
print("DataFrame Original")
print(df)
# Out:
# DataFrame Original
#        sofifa_id                                         player_url  \
# 0         158023  https://sofifa.com/player/158023/lionel-messi/...
# 1          20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2         200389  https://sofifa.com/player/200389/jan-oblak/210002
# 3         188545  https://sofifa.com/player/188545/robert-lewand...
# 4         190871  https://sofifa.com/player/190871/neymar-da-sil...
# ...          ...                                                ...
# 18939     256679  https://sofifa.com/player/256679/kevin-angulo/...
# 18940     257710  https://sofifa.com/player/257710/mengxuan-zhan...
# 18941     250989  https://sofifa.com/player/250989/zhenghao-wang...
# 18942     257697  https://sofifa.com/player/257697/zitong-chen/2...
# 18943     257936   https://sofifa.com/player/257936/yue-song/210002
#
#               short_name                            long_name  age  \
# ...

# %%
data = pd.DataFrame(df,columns=['age_range']) 
print("DataFrame Modificado")
print(df)
# Out:
# DataFrame Modificado
#        sofifa_id                                         player_url  \
# 0         158023  https://sofifa.com/player/158023/lionel-messi/...
# 1          20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2         200389  https://sofifa.com/player/200389/jan-oblak/210002
# 3         188545  https://sofifa.com/player/188545/robert-lewand...
# 4         190871  https://sofifa.com/player/190871/neymar-da-sil...
# ...          ...                                                ...
# 18939     256679  https://sofifa.com/player/256679/kevin-angulo/...
# 18940     257710  https://sofifa.com/player/257710/mengxuan-zhan...
# 18941     250989  https://sofifa.com/player/250989/zhenghao-wang...
# 18942     257697  https://sofifa.com/player/257697/zitong-chen/2...
# 18943     257936   https://sofifa.com/player/257936/yue-song/210002
#
#               short_name                            long_name  age  \
# ...

# %%
df
# Out:
#        sofifa_id                                         player_url  \
# 0         158023  https://sofifa.com/player/158023/lionel-messi/...
# 1          20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2         200389  https://sofifa.com/player/200389/jan-oblak/210002
# 3         188545  https://sofifa.com/player/188545/robert-lewand...
# 4         190871  https://sofifa.com/player/190871/neymar-da-sil...
# ...          ...                                                ...
# 18939     256679  https://sofifa.com/player/256679/kevin-angulo/...
# 18940     257710  https://sofifa.com/player/257710/mengxuan-zhan...
# 18941     250989  https://sofifa.com/player/250989/zhenghao-wang...
# 18942     257697  https://sofifa.com/player/257697/zitong-chen/2...
# 18943     257936   https://sofifa.com/player/257936/yue-song/210002
#
#               short_name                            long_name  age  \
# 0               L. Messi       Lionel Andrés Messi Cuccittini   33
# ...

# %%
df2 = pd.DataFrame(df,columns=['age_range']) 
print (df)
# Out:
#        sofifa_id                                         player_url  \
# 0         158023  https://sofifa.com/player/158023/lionel-messi/...
# 1          20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2         200389  https://sofifa.com/player/200389/jan-oblak/210002
# 3         188545  https://sofifa.com/player/188545/robert-lewand...
# 4         190871  https://sofifa.com/player/190871/neymar-da-sil...
# ...          ...                                                ...
# 18939     256679  https://sofifa.com/player/256679/kevin-angulo/...
# 18940     257710  https://sofifa.com/player/257710/mengxuan-zhan...
# 18941     250989  https://sofifa.com/player/250989/zhenghao-wang...
# 18942     257697  https://sofifa.com/player/257697/zitong-chen/2...
# 18943     257936   https://sofifa.com/player/257936/yue-song/210002
#
#               short_name                            long_name  age  \
# 0               L. Messi       Lionel Andrés Messi Cuccittini   33
# ...

# %%
print (df)
# Out:
#        sofifa_id                                         player_url  \
# 0         158023  https://sofifa.com/player/158023/lionel-messi/...
# 1          20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2         200389  https://sofifa.com/player/200389/jan-oblak/210002
# 3         188545  https://sofifa.com/player/188545/robert-lewand...
# 4         190871  https://sofifa.com/player/190871/neymar-da-sil...
# ...          ...                                                ...
# 18939     256679  https://sofifa.com/player/256679/kevin-angulo/...
# 18940     257710  https://sofifa.com/player/257710/mengxuan-zhan...
# 18941     250989  https://sofifa.com/player/250989/zhenghao-wang...
# 18942     257697  https://sofifa.com/player/257697/zitong-chen/2...
# 18943     257936   https://sofifa.com/player/257936/yue-song/210002
#
#               short_name                            long_name  age  \
# 0               L. Messi       Lionel Andrés Messi Cuccittini   33
# ...

# %%
df2 = pd.DataFrame(df,columns=[age_range']) 
print (df2)
# Out:
#         short_name  age_range
# 0              NaN        NaN
# 1              NaN        NaN
# 2              NaN        NaN
# 3              NaN        NaN
# 4              NaN        NaN
# ...            ...        ...
# 18939          NaN        NaN
# 18940          NaN        NaN
# 18941          NaN        NaN
# 18942          NaN        NaN
# 18943          NaN        NaN
#
# [18944 rows x 2 columns]

# %%
import pandas as pd
data=pd.read_csv('players_21.csv')

# %%
data['age_range']=(data['age']<23,"A")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [24], in <cell line: 1>()
# ----> 1 data['age_range']=(data['age']<23,"A")
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:3655, in DataFrame.__setitem__(self, key, value)
#    3652     self._setitem_array([key], value)
#    3653 else:
#    3654     # set column
# -> 3655     self._set_item(key, value)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:3832, in DataFrame._set_item(self, key, value)
#    3822 def _set_item(self, key, value) -> None:
#    3823     """
#    3824     Add series to DataFrame in specified column.
#    3825
#    (...)
#    3830     ensure homogeneity.
#    3831     """
# -> 3832     value = self._sanitize_column(value)
#    3834     if (
#    3835         key in self.columns
#    3836         and value.ndim == 1
#    3837         and not is_extension_array_dtype(value)
# ...

# %%
import pandas as pd
datos = pd.read_csv('players_21.csv')
df=pd.Dataframe(datos)
print("DataFrame Original")
print(df)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [25], in <cell line: 3>()
#       1 import pandas as pd
#       2 datos = pd.read_csv('players_21.csv')
# ----> 3 df=pd.Dataframe(datos)
#       4 print("DataFrame Original")
#       5 print(df)
#
# File ~\anaconda3\lib\site-packages\pandas\__init__.py:261, in __getattr__(name)
#     257     from pandas.core.arrays.sparse import SparseArray as _SparseArray
#     259     return _SparseArray
# --> 261 raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#
# AttributeError: module 'pandas' has no attribute 'Dataframe'

# %%
import pandas as pd
datos = pd.read_csv('players_21.csv')
df=pd.Dataframe(datos)
print("DataFrame Original")
print(df)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [26], in <cell line: 3>()
#       1 import pandas as pd
#       2 datos = pd.read_csv('players_21.csv')
# ----> 3 df=pd.Dataframe(datos)
#       4 print("DataFrame Original")
#       5 print(df)
#
# File ~\anaconda3\lib\site-packages\pandas\__init__.py:261, in __getattr__(name)
#     257     from pandas.core.arrays.sparse import SparseArray as _SparseArray
#     259     return _SparseArray
# --> 261 raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#
# AttributeError: module 'pandas' has no attribute 'Dataframe'

# %%
import pandas as pd

# %%
datos = pd.read_csv('players_21.csv')

# %%
  print("DataFrame Original")
print(datos)
# Out:
# DataFrame Original
#        sofifa_id                                         player_url  \
# 0         158023  https://sofifa.com/player/158023/lionel-messi/...
# 1          20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2         200389  https://sofifa.com/player/200389/jan-oblak/210002
# 3         188545  https://sofifa.com/player/188545/robert-lewand...
# 4         190871  https://sofifa.com/player/190871/neymar-da-sil...
# ...          ...                                                ...
# 18939     256679  https://sofifa.com/player/256679/kevin-angulo/...
# 18940     257710  https://sofifa.com/player/257710/mengxuan-zhan...
# 18941     250989  https://sofifa.com/player/250989/zhenghao-wang...
# 18942     257697  https://sofifa.com/player/257697/zitong-chen/2...
# 18943     257936   https://sofifa.com/player/257936/yue-song/210002
#
#               short_name                            long_name  age  \
# ...

# %%
datos = pd.DataFrame(datos,columns=['age_range']) 

print(datos)
# Out:
#        age_range
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ...          ...
# 18939        NaN
# 18940        NaN
# 18941        NaN
# 18942        NaN
# 18943        NaN
#
# [18944 rows x 1 columns]

# %%
datos = datos.assign(age_range = datos.withColumn("age_range",when(col("age") < 23,1)
      .when(col("age") < 27,2)
      .when(col("age") < 32,3)                 
      .when(col("age") >=32,4)
# Out:
#   Input In [37]
#
#     ^
# SyntaxError: unexpected EOF while parsing

# %%
datos = pd.read_csv('players_21.csv', sep=',', usecols=("short_name",
                                        "long_name",
                                        "age",
                                        "height_cm",
                                        "weight_kg",
                                        "nationality",
                                        "club_name"))

# %%
datos
# Out:
#        age_range
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ...          ...
# 18939        NaN
# 18940        NaN
# 18941        NaN
# 18942        NaN
# 18943        NaN
#
# [18944 rows x 1 columns]

# %%
datos.withColumn('age_range')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [46], in <cell line: 1>()
# ----> 1 datos.withColumn('age_range')
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
#    5572     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5573 ):
#    5574     return self[name]
# -> 5575 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'withColumn'

# %%
datos = pd.DataFrame(datos,columns=['age_range'])

# %%
datos
# Out:
#        age_range
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ...          ...
# 18939        NaN
# 18940        NaN
# 18941        NaN
# 18942        NaN
# 18943        NaN
#
# [18944 rows x 1 columns]

# %%
df3 = data.withColumn("age_range", 
      expr("case when age < '23' then 'A' " +
                       "when age < '27' then 'B' " +
                    "when age < '32' then 'D' " +
                       "else 'D' end"))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [52], in <cell line: 1>()
# ----> 1 df3 = data.withColumn("age_range",
#       2       expr("case when age < '23' then 'A' " +
#       3                        "when age < '27' then 'B' " +
#       4                     "when age < '32' then 'D' " +
#       5                        "else 'D' end"))
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
#    5572     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5573 ):
#    5574     return self[name]
# -> 5575 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'withColumn'

# %%
# Out:
#        age_range
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ...          ...
# 18939        NaN
# 18940        NaN
# 18941        NaN
# 18942        NaN
# 18943        NaN
#
# [18944 rows x 1 columns]

# %%
import pandas as pd
data=pd.read_csv('players_21.csv')

# %%
data
# Out:
#        sofifa_id                                         player_url  \
# 0         158023  https://sofifa.com/player/158023/lionel-messi/...
# 1          20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2         200389  https://sofifa.com/player/200389/jan-oblak/210002
# 3         188545  https://sofifa.com/player/188545/robert-lewand...
# 4         190871  https://sofifa.com/player/190871/neymar-da-sil...
# ...          ...                                                ...
# 18939     256679  https://sofifa.com/player/256679/kevin-angulo/...
# 18940     257710  https://sofifa.com/player/257710/mengxuan-zhan...
# 18941     250989  https://sofifa.com/player/250989/zhenghao-wang...
# 18942     257697  https://sofifa.com/player/257697/zitong-chen/2...
# 18943     257936   https://sofifa.com/player/257936/yue-song/210002
#
#               short_name                            long_name  age  \
# 0               L. Messi       Lionel Andrés Messi Cuccittini   33
# ...

# %%
df3 = data.withColumn("age_range", 
      expr("case when age < '23' then 'A' " +
                       "when age < '27' then 'B' " +
                    "when age < '32' then 'D' " +
                       "else 'D' end"))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [56], in <cell line: 1>()
# ----> 1 df3 = data.withColumn("age_range",
#       2       expr("case when age < '23' then 'A' " +
#       3                        "when age < '27' then 'B' " +
#       4                     "when age < '32' then 'D' " +
#       5                        "else 'D' end"))
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
#    5572     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5573 ):
#    5574     return self[name]
# -> 5575 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'withColumn'

# %%
from pyspark.sql.functions import when

# %%
df2 = df.withColumn("age_range", when(df.gender < 23,'A')
                                 .when(df.gender == "F","Female")
                                 .when(df.gender.isNull() ,"")
                                 .otherwise(df.gender))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [59], in <cell line: 1>()
# ----> 1 df3 = data.withColumn("age_range",
#       2       expr("case when age < '23' then 'A' " +
#       3                        "when age < '27' then 'B' " +
#       4                     "when age < '32' then 'D' " +
#       5                        "else 'D' end"))
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
#    5572     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5573 ):
#    5574     return self[name]
# -> 5575 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'withColumn'
